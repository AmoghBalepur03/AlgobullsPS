# %%
a=-5
abs(a)
# Out:
# 5

# %%
import yfinance as yf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple=yf.download("AAPL",start="2010-01-01",end="2021-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.461977
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.473148
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.370184
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.358408
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.400681
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.339035
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  133.964935
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.181198
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.054169
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.044678
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
a=[1,2,3,5]
a
# Out:
# [1, 2, 3, 5]

# %%
Apple.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.461977  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.473148  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.370184  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.358408  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.400681  447610800

# %%
Stocks=yf.download(["AAPL","KO","SPY"],start="2010-01-01",end="2021-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
Stocks.head()
# Out:
# Price      Adj Close                           Close                         \
# Ticker          AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.461977  18.209936  86.580750  7.643214  28.520000  113.330002
# 2010-01-05  6.473148  17.989653  86.809937  7.656429  28.174999  113.629997
# 2010-01-06  6.370184  17.983267  86.871048  7.534643  28.165001  113.709999
# 2010-01-07  6.358408  17.938568  87.237793  7.520714  28.094999  114.190002
# 2010-01-08  6.400681  17.606552  87.528061  7.570714  27.575001  114.570000
#
# Price           High                              Low                         \
# Ticker          AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
Stocks.to_csv("stocks.csv")

# %%
Stocks=pd.read_csv("stocks.csv")

# %%
Stocks=pd.read_csv("stocks.csv",header=[0,1])

# %%
Stocks
# Out:
#            Price   Adj Close                              Close             \
#           Ticker        AAPL         KO         SPY        AAPL         KO
# 0           Date         NaN        NaN         NaN         NaN        NaN
# 1     2010-01-04    6.461977  18.209936   86.580750    7.643214  28.520000
# 2     2010-01-05    6.473148  17.989653   86.809937    7.656429  28.174999
# 3     2010-01-06    6.370184  17.983267   86.871048    7.534643  28.165001
# 4     2010-01-07    6.358408  17.938568   87.237793    7.520714  28.094999
# ...          ...         ...        ...         ...         ...        ...
# 2765  2020-12-24  129.339035  48.019436  350.743195  131.970001  53.439999
# 2766  2020-12-28  133.964935  48.666405  353.756348  136.690002  54.160000
# 2767  2020-12-29  132.181198  48.639450  353.081421  134.869995  54.130001
# 2768  2020-12-30  131.054169  48.917999  353.585236  133.720001  54.439999
# ...

# %%
Stocks=pd.read_csv("stocks.csv",header=[0,1],index_col=[0],parse_dates=[0])

# %%
Stocks
# Out:
# Price        Adj Close                              Close             \
# Ticker            AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.461977  18.209936   86.580750    7.643214  28.520000
# 2010-01-05    6.473148  17.989653   86.809937    7.656429  28.174999
# 2010-01-06    6.370184  17.983267   86.871048    7.534643  28.165001
# 2010-01-07    6.358408  17.938568   87.237793    7.520714  28.094999
# 2010-01-08    6.400681  17.606552   87.528061    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.339035  48.019436  350.743195  131.970001  53.439999
# 2020-12-28  133.964935  48.666405  353.756348  136.690002  54.160000
# 2020-12-29  132.181198  48.639450  353.081421  134.869995  54.130001
# 2020-12-30  131.054169  48.917999  353.585236  133.720001  54.439999
# 2020-12-31  130.044678  49.277431  355.381744  132.690002  54.840000
#
# ...

# %%
Stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            names=['Price', 'Ticker'])

# %%
Stocks.describe()
# Out:
# Price     Adj Close                                  Close               \
# Ticker         AAPL           KO          SPY         AAPL           KO
# count   2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean      31.479645    31.707147   180.904857    33.777537    41.320121
# std       24.550125     8.056273    69.264220    24.572747     6.808527
# min        5.798901    16.118820    78.772263     6.858929    25.014999
# 25%       15.161384    26.191202   114.157120    17.484285    37.660000
# 50%       24.484751    31.274157   174.871811    26.987499    41.759998
# 75%       40.824093    37.042492   240.407852    43.007500    45.549999
# max      133.964935    52.243050   355.381744   136.690002    60.130001
#
# Price                       High                                    Low  \
# Ticker          SPY         AAPL           KO          SPY         AAPL
# count   2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
close=Stocks.loc[:,"Close"].copy()

# %%
close
# Out:
# Ticker            AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8-bright")

# %%
close.plot(figsize=(15,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
close.div(close.iloc[0]).mul(100)
# Out:
# Ticker             AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
norm=close.div(close.iloc[0]).mul(100)

# %%
plt.style.use("seaborn-v0_8-bright")
norm.plot(figsize=(15,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
apple=close.AAPL.copy().to_frame()

# %%
apple
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
apple.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
apple["lag1"]=apple.shift(periods=1)

# %%
apple
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
apple.AAPL.sub(apple.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2020-12-24    1.009995
# 2020-12-28    4.720001
# 2020-12-29   -1.820007
# 2020-12-30   -1.149994
# 2020-12-31   -1.029999
# Length: 2769, dtype: float64

# %%
apple["diff"]=apple.AAPL.sub(apple.lag1)

# %%
apple
# Out:
#                   AAPL        lag1      diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  1.009995
# 2020-12-28  136.690002  131.970001  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999
#
# [2769 rows x 3 columns]

# %%
apple["% change"]=apple.AAPL.div(apple.lag1)

# %%
apple
# Out:
#                   AAPL        lag1      diff  % change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151
# 2010-01-08    7.570714    7.520714  0.050000  1.006648
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712
# 2020-12-28  136.690002  131.970001  4.720001  1.035766
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297
#
# [2769 rows x 4 columns]

# %%
apple["Diff2"]=apple.AAPL.diff(periods=1)

# %%
apple
# Out:
#                   AAPL        lag1      diff  % change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999
#
# [2769 rows x 5 columns]

# %%
apple["% change 2"]=apple.AAPL.pct_change(periods=1).mul(100)

# %%
apple
# Out:
#                   AAPL        lag1      diff  % change     Diff2  % change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
del apple["% change"]

# %%
apple
# Out:
#                   AAPL        lag1      diff     Diff2  % change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.050000    0.664833
# ...                ...         ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999   -0.770265
#
# [2769 rows x 5 columns]

# %%
apple.rename(columns={'% change 2':'Change'},inplace=True)

# %%
apple
# Out:
#                   AAPL        lag1      diff     Diff2    Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.050000  0.664833
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999 -0.770265
#
# [2769 rows x 5 columns]

# %%
apple.AAPL.resample
# Out:
# <bound method NDFrame.resample of Date
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
# 2010-01-08      7.570714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2769, dtype: float64>

# %%
apple
# Out:
#                   AAPL        lag1      diff     Diff2    Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.050000  0.664833
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -1.029999 -0.770265
#
# [2769 rows x 5 columns]

# %%
del apple["Change"]

# %%
del apple["lag1"]

# %%
del apple["Diff2"]

# %%
del apple["diff"]

# %%
apple
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
ret=apple.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2020-12-24  0.007712
# 2020-12-28  0.035766
# 2020-12-29 -0.013315
# 2020-12-30 -0.008527
# 2020-12-31 -0.007703
#
# [2768 rows x 1 columns]

# %%
ret.plot(kind="hist",figsize=(12,8),bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001191
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily=ret.std()

# %%
annual_mean_ret=daily_mean_ret*252
annual_mean_ret
# Out:
# AAPL    0.300134
# dtype: float64

# %%
annual_var_return=var_daily*252

# %%
annual_std_ret=std_daily*np.sqrt(252)

# %%
annual_std_ret
# Out:
# AAPL    0.283242
# dtype: float64

# %%
ticker=["SPY","AAPL","KO","IBM","DIS","MSFT"]

# %%
Stocks=yf.download(ticker,start="2010-01-01",end="2021-01-01")
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
close=Stocks.loc[:,"Close"].copy()

# %%
norm=close.div(close.iloc[0]).mul(100)

# %%
close
# Out:
# Ticker            AAPL         DIS         IBM         KO        MSFT  \
# Date
# 2010-01-04    7.643214   32.070000  126.625237  28.520000   30.950001
# 2010-01-05    7.656429   31.990000  125.095604  28.174999   30.959999
# 2010-01-06    7.534643   31.820000  124.282982  28.165001   30.770000
# 2010-01-07    7.520714   31.830000  123.852776  28.094999   30.450001
# 2010-01-08    7.570714   31.879999  125.095604  27.575001   30.660000
# ...                ...         ...         ...        ...         ...
# 2020-12-24  131.970001  173.729996  119.206497  53.439999  222.750000
# 2020-12-28  136.690002  178.860001  119.330788  54.160000  224.960007
# 2020-12-29  134.869995  177.300003  118.355644  54.130001  224.149994
# 2020-12-30  133.720001  181.169998  118.871895  54.439999  221.679993
# 2020-12-31  132.690002  181.179993  120.344170  54.840000  222.419998
#
# Ticker             SPY
# Date
# 2010-01-04  113.330002
# 2010-01-05  113.629997
# 2010-01-06  113.709999
# ...

# %%
norm
# Out:
# Ticker             AAPL         DIS         IBM          KO        MSFT  \
# Date
# 2010-01-04   100.000000  100.000000  100.000000  100.000000  100.000000
# 2010-01-05   100.172893   99.750546   98.792000   98.790318  100.032305
# 2010-01-06    98.579511   99.220455   98.150247   98.755261   99.418416
# 2010-01-07    98.397266   99.251638   97.810499   98.509814   98.384491
# 2010-01-08    99.051443   99.407544   98.792000   96.686537   99.063002
# ...                 ...         ...         ...         ...         ...
# 2020-12-24  1726.629626  541.721227   94.141184  187.377271  719.709191
# 2020-12-28  1788.383766  557.717500   94.239340  189.901820  726.849761
# 2020-12-29  1764.571699  552.853149   93.469238  189.796635  724.232596
# 2020-12-30  1749.525753  564.920486   93.876938  190.883583  716.251978
# 2020-12-31  1736.049763  564.951651   95.039641  192.286112  718.642949
#
# Ticker             SPY
# Date
# 2010-01-04  100.000000
# 2010-01-05  100.264710
# ...

# %%
plt.style.use("seaborn-v0_8-bright")
norm.plot(figsize=(15,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397

# %%
ret.describe().T ##transpose
# Out:
#          count      mean       std       min       25%       50%       75%  \
# Ticker
# AAPL    2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# DIS     2768.0  0.000749  0.015717 -0.129846 -0.006210  0.000629  0.007901
# IBM     2768.0  0.000082  0.014132 -0.128507 -0.006321  0.000287  0.006743
# KO      2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# MSFT    2768.0  0.000841  0.016012 -0.147390 -0.006939  0.000654  0.008636
# SPY     2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#              max
# Ticker
# AAPL    0.119808
# DIS     0.144123
# IBM     0.113010
# KO      0.064796
# MSFT    0.142169
# SPY     0.090603

# %%
summary=ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.001191  0.017843
# DIS     0.000749  0.015717
# IBM     0.000082  0.014132
# KO      0.000298  0.011088
# MSFT    0.000841  0.016012
# SPY     0.000491  0.010909

# %%
summary["mean"]*=252
summary["std"]*=np.sqrt(252)

# %%
summary
# Out:
#             mean       std
# Ticker
# AAPL    0.300134  0.283242
# DIS     0.188696  0.249504
# IBM     0.020648  0.224345
# KO      0.075091  0.176009
# MSFT    0.211915  0.254185
# SPY     0.123754  0.173170

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    plt.annotate(i,xy={summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002},size=15)
plt.xlabel("Annual risk(std)",fontsize=15)
plt.ylabel("Annual return",fontsize=15)
## here std deviation is risk and mean is return
## always choose one with high reward and low risk
# Out:
# Text(0, 0.5, 'Annual return')

# %%
## Correlation and Covariance

# %%
ret
# Out:
# Ticker          AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# 2010-01-11 -0.008821 -0.016311 -0.010470  0.020308 -0.012720  0.001397
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2768 rows x 6 columns]

# %%
ret.cov()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    0.000318  0.000115  0.000110  0.000067  0.000158  0.000128
# DIS     0.000115  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM     0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO      0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT    0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY     0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
# Ticker      AAPL       DIS       IBM        KO      MSFT       SPY
# Ticker
# AAPL    1.000000  0.408513  0.436100  0.339213  0.554051  0.659557
# DIS     0.408513  1.000000  0.497775  0.486514  0.480457  0.706726
# IBM     0.436100  0.497775  1.000000  0.502436  0.533130  0.703342
# KO      0.339213  0.486514  0.502436  1.000000  0.429749  0.639324
# MSFT    0.554051  0.480457  0.533130  0.429749  1.000000  0.744601
# SPY     0.659557  0.706726  0.703342  0.639324  0.744601  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()
## you need to choose stocks which are uncorrelated.
## a good advice is to go for stocks whose corr<0.5

# %%
##Challenge 1

# %%
#choose 20 random stocks and calculate risk and reward potential, compare the covariance and coorelation. Find the best 5 to invest in the long term

# %%
##simple returns and log returns

# %%
#Mean returns are misleading because you cant do average of percentage change because that does not make sense:
#hence comes the concept of log returns

# %%
spy=yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy=spy.Close.to_frame()
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2024-07-08  555.280029
# 2024-07-09  555.820007
# 2024-07-10  561.320007
# 2024-07-11  556.479980
# 2024-07-12  559.989990
#
# [7919 rows x 1 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
spy_roll=spy.rolling(window=10)
spy_roll
# Out:
# Rolling [window=10,center=False,axis=0,method=single]

# %%
spy_roll=spy_roll.mean()

# %%
spy_roll
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2024-07-08  547.940009
# 2024-07-09  549.248010
# 2024-07-10  550.897009
# 2024-07-11  551.994006
# 2024-07-12  553.356006
#
# [7919 rows x 1 columns]

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median().head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.765625
# 1993-02-12  44.765625
# 1993-02-16  44.765625
# 1993-02-17  44.765625
# 1993-02-18  44.687500
# 1993-02-19  44.625000

# %%
##similarly we can calculate max, min etc.. of the past 10 days

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()
spy.head(52)
# Out:
#                Close     SMA50
# Date
# 1993-01-29  43.93750       NaN
# 1993-02-01  44.25000       NaN
# 1993-02-02  44.34375       NaN
# 1993-02-03  44.81250       NaN
# 1993-02-04  45.00000       NaN
# 1993-02-05  44.96875       NaN
# 1993-02-08  44.96875       NaN
# 1993-02-09  44.65625       NaN
# 1993-02-10  44.71875       NaN
# 1993-02-11  44.93750       NaN
# 1993-02-12  44.59375       NaN
# 1993-02-16  43.46875       NaN
# 1993-02-17  43.43750       NaN
# 1993-02-18  43.40625       NaN
# 1993-02-19  43.56250       NaN
# 1993-02-22  43.71875       NaN
# 1993-02-23  43.68750       NaN
# 1993-02-24  44.25000       NaN
# 1993-02-25  44.34375       NaN
# 1993-02-26  44.40625       NaN
# 1993-03-01  44.28125       NaN
# 1993-03-02  44.93750       NaN
# 1993-03-03  45.12500       NaN
# 1993-03-04  44.87500       NaN
# 1993-03-05  44.75000       NaN
# 1993-03-08  45.75000       NaN
# 1993-03-09  45.59375       NaN
# 1993-03-10  45.68750       NaN
# 1993-03-11  45.56250       NaN
# ...

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
##CHallenge 2

# %%
#graph the 50 day moving average and 200 dat moving average

# %%
spy["EMA100"]=spy.Close.ewm(span=100,min_periods=200).mean()
spy
# Out:
#                  Close       SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2024-07-08  555.280029  530.845402  488.014101  519.577951
# 2024-07-09  555.820007  531.892002  488.600001  520.295616
# 2024-07-10  561.320007  532.953202  489.249651  521.107980
# 2024-07-11  556.479980  533.881602  489.879951  521.808415
# 2024-07-12  559.989990  535.041801  490.518750  522.564486
#
# [7919 rows x 4 columns]

# %%
spy["EMA100"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left",fontsize=15)
plt.show()

# %%
#there is a method to reindex the days in the spy dataset by including holidays as well. You just have to use forwardfill or backwardfill and fill in the days

# %%
spy=yf.download("SPY",interval="1wk")
spy
#weekly data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.684109
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.263468
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.052788
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.473446
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   24.947453
# ...                ...         ...         ...         ...         ...
# 2024-06-10  533.179993  544.119995  532.049988  542.780029  541.034607
# 2024-06-17  542.080017  550.119995  541.609985  544.510010  542.759033
# 2024-06-24  544.330017  550.280029  542.440002  544.219971  544.219971
# 2024-07-01  545.630005  555.049988  542.520020  554.640015  554.640015
# 2024-07-08  555.440002  563.669983  554.190002  559.989990  559.989990
#
#                Volume
# Date
# ...

# %% [markdown]
# ##Cumulative returns, Drawdowns etc..

# %%
apple=yf.download("AAPL")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099058
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.093890
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.086999
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089152
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.091737
# ...                ...         ...         ...         ...         ...
# 2024-07-08  227.089996  227.850006  223.250000  227.820007  227.820007
# 2024-07-09  227.929993  229.399994  226.369995  228.679993  228.679993
# 2024-07-10  229.300003  233.080002  229.250000  232.979996  232.979996
# 2024-07-11  231.389999  232.389999  225.770004  227.570007  227.570007
# 2024-07-12  228.919998  232.639999  228.679993  230.539993  230.539993
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# ...

# %%
apple=apple.Close.to_frame()

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2024-07-08  227.820007   0.006518
# 2024-07-09  228.679993   0.003768
# 2024-07-10  232.979996   0.018629
# 2024-07-11  227.570007  -0.023495
# 2024-07-12  230.539993   0.012966
#
# [10986 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2024-07-08  227.820007   0.006518
# 2024-07-09  228.679993   0.003768
# 2024-07-10  232.979996   0.018629
# 2024-07-11  227.570007  -0.023495
# 2024-07-12  230.539993   0.012966
#
# [10985 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.4934343635702785

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1796.2103503331264

# %%
apple["cumreturnds"]=apple.d_returns.cumsum().apply(np.exp)
apple
# Out:
#                  Close  d_returns  cumreturnds
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2024-07-08  227.820007   0.006518  1775.018075
# 2024-07-09  228.679993   0.003768  1781.718494
# 2024-07-10  232.979996   0.018629  1815.221185
# 2024-07-11  227.570007  -0.023495  1773.070246
# 2024-07-12  230.539993   0.012966  1796.210350
#
# [10985 rows x 3 columns]

# %%
apple.d_returns.mean()*252
# Out:
# 0.17190218112150296

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4496378883372075

# %%
# how to calculate drawdowns
apple["cummax"]=apple.cumreturnds.cummax()
apple
# Out:
#                  Close  d_returns  cumreturnds       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2024-07-08  227.820007   0.006518  1775.018075  1775.018075
# 2024-07-09  228.679993   0.003768  1781.718494  1781.718494
# 2024-07-10  232.979996   0.018629  1815.221185  1815.221185
# 2024-07-11  227.570007  -0.023495  1773.070246  1815.221185
# 2024-07-12  230.539993   0.012966  1796.210350  1815.221185
#
# [10985 rows x 4 columns]

# %%
apple["drawdown"]=apple["cummax"]-apple["cumreturnds"]
apple
# Out:
#                  Close  d_returns  cumreturnds       cummax   drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-07-08  227.820007   0.006518  1775.018075  1775.018075   0.000000
# 2024-07-09  228.679993   0.003768  1781.718494  1781.718494   0.000000
# 2024-07-10  232.979996   0.018629  1815.221185  1815.221185   0.000000
# 2024-07-11  227.570007  -0.023495  1773.070246  1815.221185  42.150939
# 2024-07-12  230.539993   0.012966  1796.210350  1815.221185  19.010834
#
# [10985 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<="2023-01-05")]
# Out:
#                  Close  d_returns  cumreturnds       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple["drawdown%"]=(apple["cummax"]-apple["cumreturnds"])/apple["cummax"]

# %%
apple
# Out:
#                  Close  d_returns  cumreturnds       cummax   drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829   0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829   0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829   0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829   0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610   0.000000
# ...                ...        ...          ...          ...        ...
# 2024-07-08  227.820007   0.006518  1775.018075  1775.018075   0.000000
# 2024-07-09  228.679993   0.003768  1781.718494  1781.718494   0.000000
# 2024-07-10  232.979996   0.018629  1815.221185  1815.221185   0.000000
# 2024-07-11  227.570007  -0.023495  1773.070246  1815.221185  42.150939
# 2024-07-12  230.539993   0.012966  1796.210350  1815.221185  19.010834
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# ...

# %%
#standard things u check in algorithmic trading:

# %%
#standard deviation,meaan,correaltion,covariance,simple and log retuns,moving averages,forward fill
#cumulative returns and drawdowns

# %% [markdown]
# SMA Strategy

# %%
data=apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2024-07-08  227.820007
# 2024-07-09  228.679993
# 2024-07-10  232.979996
# 2024-07-11  227.570007
# 2024-07-12  230.539993
#
# [8445 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close     sma_s     sma_l
# Date
# 1991-01-02    0.388393       NaN       NaN
# 1991-01-03    0.383929       NaN       NaN
# 1991-01-04    0.386161       NaN       NaN
# 1991-01-07    0.386161       NaN       NaN
# 1991-01-08    0.386161       NaN       NaN
# ...                ...       ...       ...
# 2024-07-08  227.820007  196.2608  185.0734
# 2024-07-09  228.679993  197.4366  185.5098
# 2024-07-10  232.979996  198.7102  185.9981
# 2024-07-11  227.570007  199.7916  186.4352
# 2024-07-12  230.539993  200.9958  186.9175
#
# [8445 rows x 3 columns]

# %%
data.plot(figsize=(12,8),fontsize=12)
# Out:
# <Axes: xlabel='Date'>

# %%
data.dropna()
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2024-07-08  227.820007  196.260800  185.073400
# 2024-07-09  228.679993  197.436600  185.509800
# 2024-07-10  232.979996  198.710200  185.998100
# 2024-07-11  227.570007  199.791600  186.435200
# 2024-07-12  230.539993  200.995800  186.917500
#
# [8346 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)
data
# Out:
#                  Close     sma_s     sma_l  position
# Date
# 1991-01-02    0.388393       NaN       NaN        -1
# 1991-01-03    0.383929       NaN       NaN        -1
# 1991-01-04    0.386161       NaN       NaN        -1
# 1991-01-07    0.386161       NaN       NaN        -1
# 1991-01-08    0.386161       NaN       NaN        -1
# ...                ...       ...       ...       ...
# 2024-07-08  227.820007  196.2608  185.0734         1
# 2024-07-09  228.679993  197.4366  185.5098         1
# 2024-07-10  232.979996  198.7102  185.9981         1
# 2024-07-11  227.570007  199.7916  186.4352         1
# 2024-07-12  230.539993  200.9958  186.9175         1
#
# [8445 rows x 4 columns]

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data
# Out:
#                  Close     sma_s     sma_l  position  returnsb&h
# Date
# 1991-01-02    0.388393       NaN       NaN        -1         NaN
# 1991-01-03    0.383929       NaN       NaN        -1   -0.011560
# 1991-01-04    0.386161       NaN       NaN        -1    0.005797
# 1991-01-07    0.386161       NaN       NaN        -1    0.000000
# 1991-01-08    0.386161       NaN       NaN        -1    0.000000
# ...                ...       ...       ...       ...         ...
# 2024-07-08  227.820007  196.2608  185.0734         1    0.006518
# 2024-07-09  228.679993  197.4366  185.5098         1    0.003768
# 2024-07-10  232.979996  198.7102  185.9981         1    0.018629
# 2024-07-11  227.570007  199.7916  186.4352         1   -0.023495
# 2024-07-12  230.539993  200.9958  186.9175         1    0.012966
#
# [8445 rows x 5 columns]

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close     sma_s     sma_l  position  returnsb&h  strategy
# Date
# 1991-01-02    0.388393       NaN       NaN        -1         NaN       NaN
# 1991-01-03    0.383929       NaN       NaN        -1   -0.011560  0.011560
# 1991-01-04    0.386161       NaN       NaN        -1    0.005797 -0.005797
# 1991-01-07    0.386161       NaN       NaN        -1    0.000000 -0.000000
# 1991-01-08    0.386161       NaN       NaN        -1    0.000000 -0.000000
# ...                ...       ...       ...       ...         ...       ...
# 2024-07-08  227.820007  196.2608  185.0734         1    0.006518  0.006518
# 2024-07-09  228.679993  197.4366  185.5098         1    0.003768  0.003768
# 2024-07-10  232.979996  198.7102  185.9981         1    0.018629  0.018629
# 2024-07-11  227.570007  199.7916  186.4352         1   -0.023495 -0.023495
# 2024-07-12  230.539993  200.9958  186.9175         1    0.012966  0.012966
#
# [8445 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    6.324863
# strategy      1.721729
# dtype: float64

# %%
##Now we shall implement the SMA strategy

# %%
data=apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2024-07-08  227.820007
# 2024-07-09  228.679993
# 2024-07-10  232.979996
# 2024-07-11  227.570007
# 2024-07-12  230.539993
#
# [8445 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data.plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data.loc["2016",["sma_s","sma_l","position"]].plot(figsize=(12,8),title="AAPLE - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12,secondary_y="position")
# Out:
# <Axes: title={'center': 'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1);

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    6.333003
# strategy      1.680623
# dtype: float64

# %%
data[["returnsb&h","strategy"]].sum().apply(np.exp) # what 1$ will be
# Out:
# returnsb&h    562.844539
# strategy        5.368897
# dtype: float64

# %%
data[["returnsb&h","strategy"]].std()*np.sqrt(252) #annyal std
# Out:
# returnsb&h    0.432578
# strategy      0.432734
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
## Strategy adjusted to long bias

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy2"]].sum()
# Out:
# returnsb&h    6.330283
# strategy2     4.004092
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp) # what 1$ will be
# Out:
# returnsb&h    561.315156
# strategy2      54.822027
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.432604
# strategy2     0.334092
# dtype: float64

# %%
## Strategy 2 is better than strategy 1
data[["strategy","strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.432760
# strategy2    0.334092
# dtype: float64

# %% [markdown]
# # Creating our first function

# %%
##this is basically to quicken the process of manuall writing a lot of lines of code for backtesting

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start,end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std= data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy("SPY","2000-01-01","2020-01-01",(50,200))
##Now we can use this function whenever we want to test our strategy. It gives us the returns and standard deviation which is the most import metrics of a strategy
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (4.766371508372407, 0.18787947185958592)
